# %% [markdown]
# # Airline Customer Satisfaction
#
# > (c) 2021 Travis Lloyd, Isabella Oakes, Lina Nguyen
# >
# > An analysis of Airline satisfaction
# >

# %% [markdown]
# ***
# **Table of Contents**<br>
# >[Data PreProcessing](#preproc)<br>
# >[Models](#models)<br>
# >[Results](#results)<br>

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import models
from sklearn.linear_model import LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, classification_report, accuracy_score

from dmba import classificationSummary, gainsChart

from matplotlib.lines import Line2D

# %matplotlib inline
DATA = Path('.').resolve().parent / 'data'

# %%
df = pd.read_csv('Desktop/train.csv')
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %% [markdown]
# <a id="preproc"></a>
# <br>
# ## Data Preprocessing

# %%
df = df.rename(columns={'Customer Type':'customer_type',
                   'Type of Travel':'travel_type',
                   'Flight Distance':'flight_dist',
                   'Inflight wifi service':'wifi_service',
                   'Departure/Arrival time convenient':'time_convenience',
                   'Ease of Online booking':'booking_diff',
                   'Gate location':'gate_loc',
                   'Food and drink':'food_drink',
                   'Online boarding':'online_boarding', 
                   'Seat comfort':'seat_comf',
                   'Inflight entertainment':'inflight_ent', 
                   'On-board service':'onboard_serv', 
                   'Leg room service':'legroom',
                   'Baggage handling':'baggage_care', 
                   'Checkin service':'checkin',
                   'Inflight service':'inflight_serv',
                   'Departure Delay in Minutes':'dept_delay', 
                   'Arrival Delay in Minutes':'arr_delay'
                  })

# %%
# Number of unique values
for column in df.columns:
    print(column, df[column].nunique())
# Out:
# Unnamed: 0 103904
# id 103904
# Gender 2
# customer_type 2
# Age 75
# travel_type 2
# Class 3
# flight_dist 3802
# wifi_service 6
# time_convenience 6
# booking_diff 6
# gate_loc 6
# food_drink 6
# online_boarding 6
# seat_comf 6
# inflight_ent 6
# onboard_serv 6
# legroom 6
# baggage_care 5
# checkin 6
# inflight_serv 6
# Cleanliness 6
# dept_delay 446
# arr_delay 455
# satisfaction 2

# %%
# Helper Functions

classes = ('Satisfied', 'Unsatisfied')

def check_na(df):
    if df.isna().sum().sum():
        print ('Missing values detected')
    else:
        print('No Missing Values Detected')

        #Function for printing model evaluation metrics
def stat_print(train_y, pred_cancel):
    print('Recall Score    : ',recall_score(train_y, pred_cancel, average='weighted'))
    print('Accuracy Score  : ',accuracy_score(train_y, pred_cancel))
    print('F1 Score        : ',f1_score(train_y,pred_cancel))
    print('Precision Score : ',precision_score(train_y,pred_cancel))
    
    
def confusionMatrices(model, title):
    print(title + ' - training results')
    classificationSummary(train_y, model.predict(train_X), class_names=classes)
    print(title + ' - validation results')
    valid_pred = model.predict(valid_X)
    classificationSummary(valid_y, valid_pred, class_names=classes)

# %%
check_na(df)
# Out:
# Missing values detected

# %%
# Checking for na values
df.isna().sum()
# Out:
# Unnamed: 0            0
# id                    0
# Gender                0
# customer_type         0
# Age                   0
# travel_type           0
# Class                 0
# flight_dist           0
# wifi_service          0
# time_convenience      0
# booking_diff          0
# gate_loc              0
# food_drink            0
# online_boarding       0
# seat_comf             0
# inflight_ent          0
# onboard_serv          0
# legroom               0
# baggage_care          0
# checkin               0
# inflight_serv         0
# Cleanliness           0
# dept_delay            0
# arr_delay           310
# satisfaction          0
# dtype: int64

# %%
df.sort_values(by='dept_delay', ascending=False)
# Out:
#         Unnamed: 0     id  Gender   customer_type  Age      travel_type  \
# 83741        83741  73471  Female  Loyal Customer   47  Personal Travel
# 6744          6744  69661    Male  Loyal Customer   32  Business travel
# 61310        61310   4903    Male  Loyal Customer   49  Business travel
# 72206        72206  78300    Male  Loyal Customer   30  Personal Travel
# 80182        80182   8345    Male  Loyal Customer   47  Business travel
# ...            ...    ...     ...             ...  ...              ...
# 44435        44435  95245    Male  Loyal Customer   49  Personal Travel
# 44434        44434  58151  Female  Loyal Customer   42  Business travel
# 44432        44432   6253  Female  Loyal Customer    8  Personal Travel
# 44431        44431  48424    Male  Loyal Customer   47  Business travel
# 103903      103903  62567    Male  Loyal Customer   27  Business travel
#
#            Class  flight_dist  wifi_service  time_convenience  ...  \
# 83741        Eco         1120             2                 2  ...
# 6744    Business         2916             2                 2  ...
# 61310   Business         1959             1                 1  ...
# 72206        Eco         1598             1                 4  ...
# 80182   Business         2187             4                 5  ...
# ...          ...          ...           ...               ...  ...
# 44435        Eco          189             3                 1  ...
# 44434   Business         3239             5                 5  ...
# 44432        Eco          413             2                 5  ...
# 44431        Eco          819             4                 2  ...
# 103903  Business         1723             1                 3  ...
#
#         inflight_ent  onboard_serv  legroom  baggage_care  checkin  \
# 83741              2             4        4             4        2
# 6744               3             4        5             4        5
# 61310              4             4        4             5        4
# 72206              5             3        4             4        1
# 80182              5             4        5             5        4
# ...              ...           ...      ...           ...      ...
# 44435              1             1        3             3        4
# 44434              4             4        5             4        5
# 44432              5             2        3             4        4
# 44431              5             1        5             4        5
# 103903             1             1        1             4        4
#
#         inflight_serv  Cleanliness  dept_delay  arr_delay  \
# 83741               3            2        1592     1584.0
# 6744                3            5        1305     1280.0
# 61310               4            4        1017     1011.0
# 72206               4            1         978      970.0
# 80182               4            4         933      920.0
# ...               ...          ...         ...        ...
# 44435               4            1           0        0.0
# 44434               4            4           0       34.0
# 44432               2            5           0        0.0
# 44431               1            5           0        0.0
# 103903              3            1           0        0.0
#
#                    satisfaction
# 83741   neutral or dissatisfied
# 6744                  satisfied
# 61310                 satisfied
# 72206   neutral or dissatisfied
# 80182                 satisfied
# ...                         ...
# 44435   neutral or dissatisfied
# 44434                 satisfied
# 44432   neutral or dissatisfied
# 44431                 satisfied
# 103903  neutral or dissatisfied
#
# [103904 rows x 25 columns]

# %%
# Replacing arrival delay missing values based on the departing delay
df['arr_delay'].fillna(value=df['dept_delay'] -5,inplace=True)

# %%
min_value = df['flight_dist'].min()
max_value = df['flight_dist'].max()
print(min_value)
print(max_value)
# Out:
# 31
# 4983

# %%
# Turning flight length into a binned variable
bins = np.linspace(min_value,max_value,4)
bins.round(2)
# Out:
# array([  31.  , 1681.67, 3332.33, 4983.  ])

# %%
labels = ['short', 'medium', 'long']

# %%
df['flight_length'] = pd.cut(df['flight_dist'], bins=bins, labels=labels, include_lowest=True)

# %%
plt.hist(df['flight_length'], bins=3)
# Out:
# (array([76737., 21561.,  5606.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %%
df.head(2)
# Out:
#    Unnamed: 0     id Gender      customer_type  Age      travel_type  \
# 0           0  70172   Male     Loyal Customer   13  Personal Travel
# 1           1   5047   Male  disloyal Customer   25  Business travel
#
#       Class  flight_dist  wifi_service  time_convenience  ...  onboard_serv  \
# 0  Eco Plus          460             3                 4  ...             4
# 1  Business          235             3                 2  ...             1
#
#    legroom  baggage_care  checkin  inflight_serv  Cleanliness  dept_delay  \
# 0        3             4        4              5            5          25
# 1        5             3        1              4            1           1
#
#    arr_delay             satisfaction  flight_length
# 0       18.0  neutral or dissatisfied          short
# 1        6.0  neutral or dissatisfied          short
#
# [2 rows x 26 columns]

# %%
## Creating dummy variable for Gender
# Male:0, Female:1
df.loc[df['Gender'] == 'Male', 'flight_dummy'] = 0
df.loc[df['Gender'] == 'Female', 'flight_dummy'] = 1

## Creating dummy variable for customer type
# disloyal:0, loyal:1
df.loc[df['customer_type'] == 'Loyal Customer', 'flight_dummy'] = 1
df.loc[df['customer_type'] == 'disloyal Customer', 'flight_dummy'] = 0

## Creating dummy variable for travel type
# personal:0, business:1
df.loc[df['travel_type'] == 'Business travel', 'flight_dummy'] = 1
df.loc[df['travel_type'] == 'Personal Travel', 'flight_dummy'] = 0


## Creating dummy variable for flight length
#1:short, 2:medium, 3:long
df.loc[df['flight_length'] == 'short', 'flight_dummy'] = 1
df.loc[df['flight_length'] == 'medium', 'flight_dummy'] = 2
df.loc[df['flight_length'] == 'long', 'flight_dummy'] = 3

## Creating dummy variable for Class
#1:Eco, 2:Eco Plus 3:Business
df.loc[df['Class'] == 'Eco', 'class_dummy'] = 1
df.loc[df['Class'] == 'Eco Plus', 'class_dummy'] = 2
df.loc[df['Class'] == 'Business', 'class_dummy'] = 3


## Creating dummy variable for satisfaction (1 for satisfied)
df.loc[df['satisfaction'] == 'neutral or dissatisfied', 'satisfaction_dummy'] = 0
df.loc[df['satisfaction'] == 'satisfied', 'satisfaction_dummy'] = 1

# %%
df = df.drop(columns=['travel_type','customer_type','flight_dist','flight_length','satisfaction','Class','Gender'])

df.head(30)
# Out:
#     Unnamed: 0      id  Age  wifi_service  time_convenience  booking_diff  \
# 0            0   70172   13             3                 4             3
# 1            1    5047   25             3                 2             3
# 2            2  110028   26             2                 2             2
# 3            3   24026   25             2                 5             5
# 4            4  119299   61             3                 3             3
# 5            5  111157   26             3                 4             2
# 6            6   82113   47             2                 4             2
# 7            7   96462   52             4                 3             4
# 8            8   79485   41             1                 2             2
# 9            9   65725   20             3                 3             3
# 10          10   34991   24             4                 5             5
# 11          11   51412   12             2                 4             2
# 12          12   98628   53             1                 4             4
# 13          13   83502   33             4                 2             4
# 14          14   95789   26             3                 2             3
# 15          15  100580   13             2                 1             2
# 16          16   71142   26             3                 3             3
# 17          17  127461   41             4                 4             2
# 18          18   70354   45             4                 4             4
# 19          19   66246   38             2                 3             3
# 20          20   39076    9             2                 4             2
# 21          21   22434   17             3                 1             3
# 22          22   43510   43             3                 5             3
# 23          23  114090   58             4                 5             4
# 24          24  105420   23             5                 0             5
# 25          25  102956   57             4                 4             4
# 26          26   18510   33             1                 1             1
# 27          27   14925   49             4                 4             4
# 28          28  118319   36             3                 1             1
# 29          29   75460   22             3                 2             3
#
#     gate_loc  food_drink  online_boarding  seat_comf  ...  legroom  \
# 0          1           5                3          5  ...        3
# 1          3           1                3          1  ...        5
# 2          2           5                5          5  ...        3
# 3          5           2                2          2  ...        5
# 4          3           4                5          5  ...        4
# 5          1           1                2          1  ...        4
# 6          3           2                2          2  ...        3
# 7          4           5                5          5  ...        5
# 8          2           4                3          3  ...        2
# 9          4           2                3          3  ...        3
# 10         4           2                5          2  ...        3
# 11         2           1                2          1  ...        2
# 12         4           1                1          1  ...        1
# 13         3           4                4          4  ...        5
# 14         2           2                3          2  ...        3
# 15         3           4                2          1  ...        1
# 16         3           4                4          4  ...        3
# 17         4           4                4          4  ...        5
# 18         4           3                4          5  ...        5
# 19         2           5                3          5  ...        2
# 20         4           2                2          1  ...        5
# 21         3           5                3          5  ...        5
# 22         5           5                4          5  ...        3
# 23         5           4                3          4  ...        4
# 24         1           1                5          1  ...        5
# 25         1           5                4          5  ...        2
# 26         1           1                5          3  ...        4
# 27         4           2                2          1  ...        4
# 28         1           1                2          1  ...        3
# 29         3           3                3          1  ...        4
#
#     baggage_care  checkin  inflight_serv  Cleanliness  dept_delay  arr_delay  \
# 0              4        4              5            5          25       18.0
# 1              3        1              4            1           1        6.0
# 2              4        4              4            5           0        0.0
# 3              3        1              4            2          11        9.0
# 4              4        3              3            3           0        0.0
# 5              4        4              4            1           0        0.0
# 6              4        3              5            2           9       23.0
# 7              5        4              5            4           4        0.0
# 8              1        4              1            2           0        0.0
# 9              4        4              3            2           0        0.0
# 10             5        3              5            2           0        0.0
# 11             5        5              5            1           0        0.0
# 12             3        4              4            1          28        8.0
# 13             2        2              2            4           0        0.0
# 14             2        2              1            2          43       35.0
# 15             4        1              3            4           1        0.0
# 16             4        5              4            4          49       51.0
# 17             5        3              5            5           0       10.0
# 18             5        3              5            4           7        5.0
# 19             4        3              2            5          17       18.0
# 20             3        4              3            2           0        4.0
# 21             3        3              4            5           0        0.0
# 22             5        3              3            4          52       29.0
# 23             4        2              4            2           0        0.0
# 24             5        3              5            1          54       44.0
# 25             4        4              5            5          27       28.0
# 26             3        5              4            2           0        0.0
# 27             4        2              4            2           0        8.0
# 28             3        2              3            2          18       12.0
# 29             3        4              2            3          19        0.0
#
#     flight_dummy  class_dummy  satisfaction_dummy
# 0            1.0          2.0                 0.0
# 1            1.0          3.0                 0.0
# 2            1.0          3.0                 1.0
# 3            1.0          3.0                 0.0
# 4            1.0          3.0                 1.0
# 5            1.0          1.0                 0.0
# 6            1.0          1.0                 0.0
# 7            2.0          3.0                 1.0
# 8            1.0          3.0                 0.0
# 9            1.0          1.0                 0.0
# 10           1.0          1.0                 0.0
# 11           1.0          2.0                 0.0
# 12           1.0          1.0                 0.0
# 13           1.0          1.0                 1.0
# 14           1.0          1.0                 0.0
# 15           1.0          1.0                 0.0
# 16           2.0          3.0                 1.0
# 17           2.0          3.0                 1.0
# 18           2.0          3.0                 1.0
# 19           1.0          1.0                 0.0
# 20           1.0          1.0                 0.0
# 21           1.0          1.0                 0.0
# 22           1.0          1.0                 0.0
# 23           2.0          1.0                 0.0
# 24           1.0          1.0                 1.0
# 25           1.0          1.0                 0.0
# 26           1.0          3.0                 1.0
# 27           1.0          2.0                 1.0
# 28           3.0          3.0                 0.0
# 29           2.0          1.0                 0.0
#
# [30 rows x 22 columns]

# %%
df.corr()
# Out:
#                     Unnamed: 0        id       Age  wifi_service  \
# Unnamed: 0            1.000000  0.002991  0.004786     -0.002490
# id                    0.002991  1.000000  0.022857     -0.021276
# Age                   0.004786  0.022857  1.000000      0.017859
# wifi_service         -0.002490 -0.021276  0.017859      1.000000
# time_convenience      0.000739 -0.002110  0.038125      0.343845
# booking_diff          0.001913  0.014163  0.024842      0.715856
# gate_loc              0.005073 -0.000606 -0.001330      0.336248
# food_drink           -0.002162  0.001063  0.023000      0.134718
# online_boarding       0.001002  0.055477  0.208939      0.456970
# seat_comf             0.000044  0.052903  0.160277      0.122658
# inflight_ent          0.001363  0.002300  0.076444      0.209321
# onboard_serv          0.000813  0.055241  0.057594      0.121500
# legroom               0.004052  0.044634  0.040583      0.160473
# baggage_care         -0.000526  0.074940 -0.047529      0.120923
# checkin              -0.004321  0.079273  0.035482      0.043193
# inflight_serv        -0.000134  0.079346 -0.049427      0.110441
# Cleanliness          -0.001117  0.024965  0.053611      0.132698
# dept_delay           -0.000045 -0.019546 -0.010152     -0.017402
# arr_delay             0.000584 -0.037310 -0.012133     -0.019035
# flight_dummy          0.002144  0.064137  0.114496      0.004179
# class_dummy           0.000798  0.095698  0.140565      0.036279
# satisfaction_dummy   -0.004731  0.013734  0.137167      0.284245
#
#                     time_convenience  booking_diff  gate_loc  food_drink  \
# Unnamed: 0                  0.000739      0.001913  0.005073   -0.002162
# id                         -0.002110      0.014163 -0.000606    0.001063
# Age                         0.038125      0.024842 -0.001330    0.023000
# wifi_service                0.343845      0.715856  0.336248    0.134718
# time_convenience            1.000000      0.436961  0.444757    0.004906
# booking_diff                0.436961      1.000000  0.458655    0.031873
# gate_loc                    0.444757      0.458655  1.000000   -0.001159
# food_drink                  0.004906      0.031873 -0.001159    1.000000
# online_boarding             0.070119      0.404074  0.001688    0.234468
# seat_comf                   0.011344      0.030014  0.003669    0.574556
# inflight_ent               -0.004861      0.047032  0.003517    0.622512
# onboard_serv                0.068882      0.038833 -0.028373    0.059073
# legroom                     0.012441      0.107601 -0.005873    0.032498
# baggage_care                0.072126      0.038762  0.002313    0.034746
# checkin                     0.093333      0.011081 -0.035427    0.087299
# inflight_serv               0.073318      0.035272  0.001681    0.033993
# Cleanliness                 0.014292      0.016179 -0.003830    0.657760
# dept_delay                  0.001005     -0.006371  0.005467   -0.029926
# arr_delay                  -0.000663     -0.008045  0.005097   -0.032462
# flight_dummy               -0.031174      0.054428  0.007898    0.052659
# class_dummy                -0.092788      0.106391  0.004150    0.085908
# satisfaction_dummy         -0.051601      0.171705  0.000682    0.209936
#
#                     online_boarding  seat_comf  ...   legroom  baggage_care  \
# Unnamed: 0                 0.001002   0.000044  ...  0.004052     -0.000526
# id                         0.055477   0.052903  ...  0.044634      0.074940
# Age                        0.208939   0.160277  ...  0.040583     -0.047529
# wifi_service               0.456970   0.122658  ...  0.160473      0.120923
# time_convenience           0.070119   0.011344  ...  0.012441      0.072126
# booking_diff               0.404074   0.030014  ...  0.107601      0.038762
# gate_loc                   0.001688   0.003669  ... -0.005873      0.002313
# food_drink                 0.234468   0.574556  ...  0.032498      0.034746
# online_boarding            1.000000   0.420211  ...  0.123950      0.083280
# seat_comf                  0.420211   1.000000  ...  0.105559      0.074542
# inflight_ent               0.285066   0.610590  ...  0.299692      0.378210
# onboard_serv               0.155443   0.131971  ...  0.355495      0.519134
# legroom                    0.123950   0.105559  ...  1.000000      0.369544
# baggage_care               0.083280   0.074542  ...  0.369544      1.000000
# checkin                    0.204462   0.191854  ...  0.153137      0.233122
# inflight_serv              0.074573   0.069218  ...  0.368656      0.628561
# Cleanliness                0.331517   0.678534  ...  0.096370      0.095793
# dept_delay                -0.018982  -0.027898  ...  0.014363     -0.005573
# arr_delay                 -0.022382  -0.030420  ...  0.011924     -0.008436
# flight_dummy               0.199445   0.150595  ...  0.127947      0.055853
# class_dummy                0.322924   0.227444  ...  0.204964      0.160460
# satisfaction_dummy         0.503557   0.349459  ...  0.313131      0.247749
#
#                      checkin  inflight_serv  Cleanliness  dept_delay  \
# Unnamed: 0         -0.004321      -0.000134    -0.001117   -0.000045
# id                  0.079273       0.079346     0.024965   -0.019546
# Age                 0.035482      -0.049427     0.053611   -0.010152
# wifi_service        0.043193       0.110441     0.132698   -0.017402
# time_convenience    0.093333       0.073318     0.014292    0.001005
# booking_diff        0.011081       0.035272     0.016179   -0.006371
# gate_loc           -0.035427       0.001681    -0.003830    0.005467
# food_drink          0.087299       0.033993     0.657760   -0.029926
# online_boarding     0.204462       0.074573     0.331517   -0.018982
# seat_comf           0.191854       0.069218     0.678534   -0.027898
# inflight_ent        0.120867       0.404855     0.691815   -0.027489
# onboard_serv        0.243914       0.550782     0.123220   -0.031569
# legroom             0.153137       0.368656     0.096370    0.014363
# baggage_care        0.233122       0.628561     0.095793   -0.005573
# checkin             1.000000       0.237197     0.179583   -0.018453
# inflight_serv       0.237197       1.000000     0.088779   -0.054813
# Cleanliness         0.179583       0.088779     1.000000   -0.014093
# dept_delay         -0.018453      -0.054813    -0.014093    1.000000
# arr_delay          -0.020740      -0.059499    -0.016015    0.965743
# flight_dummy        0.062597       0.050482     0.087154   -0.002103
# class_dummy         0.151613       0.156353     0.135818   -0.009637
# satisfaction_dummy  0.236174       0.244741     0.305198   -0.050494
#
#                     arr_delay  flight_dummy  class_dummy  satisfaction_dummy
# Unnamed: 0           0.000584      0.002144     0.000798           -0.004731
# id                  -0.037310      0.064137     0.095698            0.013734
# Age                 -0.012133      0.114496     0.140565            0.137167
# wifi_service        -0.019035      0.004179     0.036279            0.284245
# time_convenience    -0.000663     -0.031174    -0.092788           -0.051601
# booking_diff        -0.008045      0.054428     0.106391            0.171705
# gate_loc             0.005097      0.007898     0.004150            0.000682
# food_drink          -0.032462      0.052659     0.085908            0.209936
# online_boarding     -0.022382      0.199445     0.322924            0.503557
# seat_comf           -0.030420      0.150595     0.227444            0.349459
# inflight_ent        -0.030475      0.127486     0.194366            0.398059
# onboard_serv        -0.035280      0.102915     0.209505            0.322383
# legroom              0.011924      0.127947     0.204964            0.313131
# baggage_care        -0.008436      0.055853     0.160460            0.247749
# checkin             -0.020740      0.062597     0.151613            0.236174
# inflight_serv       -0.059499      0.050482     0.156353            0.244741
# Cleanliness         -0.016015      0.087154     0.135818            0.305198
# dept_delay           0.965743     -0.002103    -0.009637           -0.050494
# arr_delay            1.000000     -0.004797    -0.013647           -0.057518
# flight_dummy        -0.004797      1.000000     0.432710            0.290353
# class_dummy         -0.013647      0.432710     1.000000            0.494471
# satisfaction_dummy  -0.057518      0.290353     0.494471            1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle('Correlation between Guest Satisfaction and Predictors',fontsize=20)
ax=sns.heatmap(df.corr()[['satisfaction_dummy']].sort_values("satisfaction_dummy"),vmax=1, vmin=-1, cmap="rocket", annot=True, ax=ax);
ax.invert_yaxis()

# %% [markdown]
# #### Distribution of highly correlated variables

# %%
dfog = pd.read_csv('Desktop/train.csv')

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.suptitle('Absolute vs Normalized Distributions')
ctonline = pd.crosstab(dfog['Online boarding'], dfog['satisfaction'])
ctonlinenorm = ctonline.div(ctonline.sum(1), axis=0)

plotonline = ctonline.plot(kind='bar', stacked = True, title = 'Online Boarding and Satisfaction',
                          ax = ax1, color = ['#90CDBC', '#991857'])

plotonlinenorm = ctonlinenorm.plot(kind='bar', stacked = True, title = 'Online Boarding and Satisfaction Normalized',
                                  ax = ax2, color = ['#90CDBC', '#991857'])
# Out:
# C:\Users\LadyBug\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.suptitle('Absolute vs Normalized Distributions')
ctclass = pd.crosstab(dfog['Class'], dfog['satisfaction'])
ctclassnorm = ctclass.div(ctclass.sum(1), axis=0)

plotclass = ctclass.plot(kind='bar', stacked = True, title = 'Class and Satisfaction',
                          ax = ax1, color = ['#90CDBC', '#991857'])

plotclassnorm = ctclassnorm.plot(kind='bar', stacked = True, title = 'Class and Satisfaction Normalized',
                                  ax = ax2, color = ['#90CDBC', '#991857'])

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.suptitle('Absolute vs Normalized Distributions')
ctentertain = pd.crosstab(dfog['Inflight entertainment'], dfog['satisfaction'])
ctentertainnorm = ctentertain.div(ctentertain.sum(1), axis=0)

plotentertain = ctentertain.plot(kind='bar', stacked = True, title = 'In-flight entertainment and Satisfaction',
                          ax = ax1, color = ['#90CDBC', '#991857'])

plotentertainnorm = ctentertainnorm.plot(kind='bar', stacked = True, title = 'In-flight entertainment and Satisfaction Normalized',
                                  ax = ax2, color = ['#90CDBC', '#991857'])

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
fig.suptitle('Absolute vs Normalized Distributions')
ctseat = pd.crosstab(dfog['Seat comfort'], dfog['satisfaction'])
ctseatnorm = ctseat.div(ctseat.sum(1), axis=0)

plotseat = ctseat.plot(kind='bar', stacked = True, title = 'Seat Comfort and Satisfaction',
                          ax = ax1, color = ['#90CDBC', '#991857'])

plotseatnorm = ctseatnorm.plot(kind='bar', stacked = True, title = 'Seat Comfort and Satisfaction Normalized',
                                  ax = ax2, color = ['#90CDBC', '#991857'])

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Age', 'wifi_service', 'time_convenience',
#        'booking_diff', 'gate_loc', 'food_drink', 'online_boarding',
#        'seat_comf', 'inflight_ent', 'onboard_serv', 'legroom', 'baggage_care',
#        'checkin', 'inflight_serv', 'Cleanliness', 'dept_delay', 'arr_delay',
#        'flight_dummy', 'class_dummy', 'satisfaction_dummy'],
#       dtype='object')

# %%
predictors = ['Age', 'wifi_service','booking_diff', 'food_drink', 'online_boarding','seat_comf',
              'inflight_ent', 'onboard_serv', 'legroom', 'baggage_care', 'checkin', 'inflight_serv',
              'Cleanliness','flight_dummy', 'class_dummy']
outcome = ['satisfaction_dummy']

# %%
X = df[predictors]
y = df[outcome]

# %%
train_X, valid_X, train_y, valid_y = train_test_split(X,y,train_size=.7,random_state=1)
train_X.shape, valid_X.shape
# Out:
# ((72732, 15), (31172, 15))

# %% [markdown]
# <a id="models"></a>
# <br>
# # Classification Models

# %% [markdown]
# ### _Logistic Regression Model_

# %%
logit = LogisticRegressionCV(penalty='l2', solver='saga', cv=5, max_iter=110000).fit(train_X, train_y.values.ravel())

# %%
logit_confusion = confusionMatrices(logit, 'Logistic regression')
# Out:
# Logistic regression - training results
# Confusion Matrix (Accuracy 0.8428)
#
#             Prediction
#      Actual   Satisfied Unsatisfied
#   Satisfied       36156        5031
# Unsatisfied        6404       25141
# Logistic regression - validation results
# Confusion Matrix (Accuracy 0.8461)
#
#             Prediction
#      Actual   Satisfied Unsatisfied
#   Satisfied       15599        2093
# Unsatisfied        2704       10776

# %% [markdown]
# ### _Decision Tree_

# %%
dtree = DecisionTreeClassifier().fit(train_X, train_y)
tree_confusion = confusionMatrices(dtree, 'Decision Tree')
# Out:
# Decision Tree - training results
# Confusion Matrix (Accuracy 0.9998)
#
#             Prediction
#      Actual   Satisfied Unsatisfied
#   Satisfied       41186           1
# Unsatisfied          16       31529
# Decision Tree - validation results
# Confusion Matrix (Accuracy 0.9237)
#
#             Prediction
#      Actual   Satisfied Unsatisfied
#   Satisfied       16451        1241
# Unsatisfied        1138       12342

# %%
rf = RandomForestClassifier(n_estimators=100).fit(train_X, train_y.values.ravel())

# %%
forest_confusion = confusionMatrices(rf, 'Random Forest')
# Out:
# Random Forest - training results
# Confusion Matrix (Accuracy 0.9997)
#
#             Prediction
#      Actual   Satisfied Unsatisfied
#   Satisfied       41176          11
# Unsatisfied           8       31537
# Random Forest - validation results
# Confusion Matrix (Accuracy 0.9477)
#
#             Prediction
#      Actual   Satisfied Unsatisfied
#   Satisfied       17078         614
# Unsatisfied        1015       12465

# %%
results = []
values = [1, 3, 5, 7, 9, 11, 13, 15, 17]
for k in values:
    knn = KNeighborsClassifier(n_neighbors=k).fit(train_X, train_y)
    results.append({
        'k': k,
        'accuracy': accuracy_score(valid_y, knn.predict(valid_X))
    })
results = pd.DataFrame(results)
results
# Out:
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
#     k  accuracy
# 0   1  0.893141
# 1   3  0.902733
# 2   5  0.906775
# 3   7  0.908026
# 4   9  0.907128
# 5  11  0.906775
# 6  13  0.904786
# 7  15  0.903952
# 8  17  0.903343

# %%
knn = KNeighborsClassifier(n_neighbors=7).fit(train_X, train_y)
knn_confusion = confusionMatrices(knn, 'k-NN Model')
# Out:
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# k-NN Model - training results
# Confusion Matrix (Accuracy 0.9272)
#
#             Prediction
#      Actual   Satisfied Unsatisfied
#   Satisfied       39659        1528
# Unsatisfied        3764       27781
# k-NN Model - validation results
# Confusion Matrix (Accuracy 0.9080)
#
#             Prediction
#      Actual   Satisfied Unsatisfied
#   Satisfied       16823         869
# Unsatisfied        1998       11482

# %% [markdown]
# <a id="results"></a>
# <br>
# # Results

# %%
# Loading Test Data
dftest = pd.read_csv('Desktop/test.csv')
dftest = dftest.rename(columns={'Customer Type':'customer_type',
                   'Type of Travel':'travel_type',
                   'Flight Distance':'flight_dist',
                   'Inflight wifi service':'wifi_service',
                   'Departure/Arrival time convenient':'time_convenience',
                   'Ease of Online booking':'booking_diff',
                   'Gate location':'gate_loc',
                   'Food and drink':'food_drink',
                   'Online boarding':'online_boarding', 
                   'Seat comfort':'seat_comf',
                   'Inflight entertainment':'inflight_ent', 
                   'On-board service':'onboard_serv', 
                   'Leg room service':'legroom',
                   'Baggage handling':'baggage_care', 
                   'Checkin service':'checkin',
                   'Inflight service':'inflight_serv',
                   'Departure Delay in Minutes':'dept_delay', 
                   'Arrival Delay in Minutes':'arr_delay'
                  })
predictorstest = ['Age', 'wifi_service','booking_diff', 'food_drink', 'online_boarding','seat_comf',
              'inflight_ent', 'onboard_serv', 'legroom', 'baggage_care', 'checkin', 'inflight_serv',
              'Cleanliness','flight_dummy', 'class_dummy']
outcometest = ['satisfaction_dummy']
X_test = df[predictorstest]
y_test = df[outcometest]

# %%
dtree_pred_test = dtree.predict(X_test)
print(accuracy_score(y_test,dtree_pred_test))
dtree_roc = metrics.roc_curve(y_test, dtree_pred_test)
dtree_auc = metrics.auc(dtree_roc[0], dtree_roc[1])
dtree_plot = metrics.RocCurveDisplay(dtree_roc[0], dtree_roc[1],
roc_auc=dtree_auc, estimator_name='Decision Tree')
# Out:
# 0.9769402525408069
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass fpr=[0.         0.02109411 1.        ], tpr=[0.         0.97436979 1.        ] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
logit_pred_test = logit.predict(X_test)
print(accuracy_score(y_test,logit_pred_test))
logit_roc = metrics.roc_curve(y_test, logit_pred_test)
logit_auc = metrics.auc(logit_roc[0], logit_roc[1])
logit_plot = metrics.RocCurveDisplay(logit_roc[0], logit_roc[1],
roc_auc=logit_auc, estimator_name='Logistic Regression')
# Out:
# 0.8437788728056668
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass fpr=[0.        0.1209939 1.       ], tpr=[0.         0.79771238 1.        ] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
rf_pred_test = rf.predict(X_test)
print(accuracy_score(y_test,rf_pred_test))
rf_roc = metrics.roc_curve(y_test, rf_pred_test)
rf_auc = metrics.auc(rf_roc[0], rf_roc[1])
rf_plot = metrics.RocCurveDisplay(rf_roc[0], logit_roc[1],
roc_auc=rf_auc, estimator_name='Random Forest')
# Out:
# 0.984139205420388
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass fpr=[0.         0.01061499 1.        ], tpr=[0.         0.79771238 1.        ] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
knn_pred_test = knn.predict(X_test)
print(accuracy_score(y_test,knn_pred_test))
knn_roc = metrics.roc_curve(y_test, knn_pred_test)
knn_auc = metrics.auc(knn_roc[0], knn_roc[1])
knn_plot = metrics.RocCurveDisplay(knn_roc[0], knn_roc[1],
roc_auc=knn_auc, estimator_name='k-Nearest Neighbors')
# Out:
# 0.9214755928549431
# C:\Users\LadyBug\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass fpr=[0.         0.04071061 1.        ], tpr=[0.         0.87202665 1.        ] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
# Plotting ROC Curves for models
fig, ax = plt.subplots(figsize=(12,8))
fig.suptitle('ROC Curves for Models', fontsize=12)
plt.plot([0, 1], [0, 1], linestyle = '--', color = '#174ab0')
plt.xlabel('',fontsize=12)
plt.ylabel('',fontsize=12)

logit_plot.plot(ax)
dtree_plot.plot(ax)
rf_plot.plot(ax)
knn_plot.plot(ax)
plt.show()

# %%
from dmba import liftChart
logisticchart = pd.Series(logit.predict_proba(X_test)[:, 1])
logisticchart = logisticchart.sort_values(ascending=False)
dtreechart = pd.Series(dtree.predict_proba(X_test)[:, 1])
dtreechart = dtreechart.sort_values(ascending=False)
rfchart = pd.Series(rf.predict_proba(X_test)[:, 1])
rfchart = rfchart.sort_values(ascending=False)
knnchart = pd.Series(knn.predict_proba(X_test)[:, 1])
knnchart = knnchart.sort_values(ascending=False)

ax= gainsChart(logisticchart, figsize=[7,7])
gainsChart(dtreechart, color='palevioletred', ax=ax)
gainsChart(rfchart, color='green', ax=ax)
gainsChart(knnchart, color='purple', ax=ax)

ax.set_title('Cumulative Gains Chart for Models')
colors = ['royalblue', 'palevioletred', 'green', 'purple']
lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in colors]
labels=['Logistic Regression', 'Decision Tree', 'Random Forest', 'k-NN'
        'Random Predictors']
plt.legend(lines, labels)
